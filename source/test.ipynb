# %%
import pandas as pd
import numpy as np

# %%
nutri = pd.read_csv("/home/siun97/Diet/KDD2024/Siun_new_LAB/KDD2025/new_AGGBART/data/total_nutri_data.csv")

# %%
test = pd.read_csv("/home/siun97/Diet/KDD2024/Siun_new_LAB/KDD2025/new_AGGBART/data/train_pair_diet.csv").to_numpy()

# %%
before = test[0][:13].tolist()
after = test[0][:13].tolist()
allergy = test[0][-1].split(",")

# %%
a = ['<s>']+after+['</s>']+allergy+['</s>']

# %%
while len(a) < 21:
    a = a + ['</s>']

# %%
# Out:
# ['<s>',
#  '납작김밥',
#  '새알미역국',
#  '느타리버섯무침',
#  '쌀밥',
#  '단호박김치국',
#  '순살찜닭',
#  '애호박볶음',
#  '깍두기',
#  '소고기가지덮밥',
#  '북어미역국',
#  '춘권튀김',
#  'empty',
#  '단무지',
#  '</s>',
#  '난류',
#  '밀',
#  '대두',
#  '</s>',
#  '</s>',
#  '</s>']

# %%
d[15:-1]
# Out:
# ['난류', '밀', '대두', '</s>', '</s>']
